# %% [markdown]
# <a href="https://colab.research.google.com/github/orenchausho99/Polyp_segmentation_-_detection_Project/blob/main/Polyp_segmentation_%26_detection_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
